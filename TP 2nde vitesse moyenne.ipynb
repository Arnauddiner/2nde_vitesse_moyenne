# %% [markdown]
# # TP Vitesse moyenne 2nde
#
# ## 2ème partie : Utilisation d'un langage de programmation

# %% [markdown]
# <div class="bg-info">
#
# <b>Situation :
#
# Gwen souhaite se rendre à Limoges après son cours de physique du mercredi midi . Elle repère le trajet sur Google Maps, 3 trajets lui sont proposés. :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Programme 1

# %% [markdown]
# <div class="bg-info">
#
# <center><b> Exécuter le programme ci-dessous qui permet de calculer puis d'afficher une vitesse moyenne.
# <div>Pour exécuter la cellule faire Schift+entrée

# %%
d_km=530
t_min=346

t_heure=t_min/60

v_moy=d_km/t_heure

print("La vitesse moyenne vaut ",v_moy ," km/h.")

# %% [markdown]
# <b> Sur votre compte rendu, répondre aux questions suivantes :
#     2. Ce programme contient 4 variables. Les nommer en disant à quoi elles correspondent.
#     3. Que permet la ligne 4 ?
#     4. Que permet la ligne 6 ?
#     5. Que permet la commande print( ) ?

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <center><b>Remarque :</b> Pour faire apparaitre les numéros de lignes, View puis Toggle line numbers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Programme 2

# %% [markdown]
# <div class="bg-info">
#
# <center><b> Exécuter le programme ci-dessous

# %%
d_km=input("Valeur de la distance : ")
t_min=346

d_km=float(d_km)

t_heure=t_min/60

v_moy=d_km/t_heure
v_moy=round(v_moy,1) #permet d'afficher le résultat avec 1 chiffre après la virgule
print("La vitesse moyenne vaut ",v_moy," km/h.")

# %% [markdown]
# <b> Sur votre compte rendu, répondre aux questions suivantes :
#     1. Qu'est-ce qui est différent par rapport au programme précédent ?
#     2. Quelle fonction est utilisée pour générer une boîte de dialogue ?
#     3. Quand on utilise cette fonction, la grandeur stockée est un texte qui ne peut être utilisé pour effectuer des calculs.
#     On doit alors convertir ce texte en nombre décimal. Quelle ligne permet cette conversion ? Quelle fonction est utilisée.
#     4. Modifier le programme pour qu'il demande à l'utilisateur de rentrer la valeur de la durée du trajet. Tester votre programme pour voir s'il fonctionne.

# %% [markdown]
# # Calculer des vitesses moyennes
#
# <b> A l’aide du programme, calculer les vitesses moyennes en km/h des 3 trajets proposés par Google Maps.
# Rédiger un petit paragraphe pour commenter les valeurs obtenues en précisant quel trajet a la vitesse moyenne la plus élevée, quels sont les avantages/inconvénients des trajets proposés etc. Quel trajet choisiriez-vous ?.
